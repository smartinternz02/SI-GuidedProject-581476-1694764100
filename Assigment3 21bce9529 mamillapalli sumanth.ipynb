# %% [markdown]
# Dowloaded the dataset

# %% [markdown]
# Loading the data set

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:/Users/mamil/Downloads/penguins_size.csv")
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %% [markdown]
# Univariate Visualizations

# %% [markdown]
# Histogram

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.histplot(df['culmen_length_mm'])
plt.show()
# Out:
# c:\Users\mamil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\mamil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.distplot(df['culmen_length_mm'])
plt.show()
# Out:
# C:\Users\mamil\AppData\Local\Temp\ipykernel_15076\1804032904.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['culmen_length_mm'])
# c:\Users\mamil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
df['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
sns.histplot(df['species'].value_counts(),x=df['species'])
plt.show()
# Out:
# c:\Users\mamil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\mamil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\mamil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
sns.histplot(df['sex'].value_counts(),x=df['sex'],fill=True,color='blueviolet')
# Out:
# c:\Users\mamil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\mamil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\mamil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='sex', ylabel='Count'>

# %%
sex_counts = df['sex'].value_counts()

# Create a barplot
sns.barplot(x=sex_counts.index, y=sex_counts.values)
sex_counts.index
# sex_counts.values
# Out:
# c:\Users\mamil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\mamil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\mamil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Index(['MALE', 'FEMALE', '.'], dtype='object', name='sex')

# %%
plt.pie(sex_counts.values,explode=[0,0,1],autopct="%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x2bd14a20cd0>,
# ...
#  [Text(-0.010346371834497005, 1.0999513410100752, ''),
#   Text(-1.029894329174279e-07, -1.0999999999999954, ''),
#   Text(2.0999071025595013, -0.019752483898488604, '')],
#  [Text(-0.005643475546089275, 0.5999734587327682, '50.3%'),
#   Text(-5.617605431859703e-08, -0.5999999999999974, '49.4%'),
#   Text(1.5999292209977152, -0.015049511541705602, '0.3%')])

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
plt.plot(df['body_mass_g'])

# %%
plt.plot(df['culmen_depth_mm'])

# %%
sns.boxplot(df['body_mass_g'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['culmen_depth_mm'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['flipper_length_mm'])
# Out:
# <Axes: >

# %%
sns.scatterplot(df['body_mass_g'])
# Out:
# c:\Users\mamil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\mamil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: ylabel='body_mass_g'>

# %%
sns.scatterplot(df['culmen_depth_mm'])
# Out:
# c:\Users\mamil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\mamil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: ylabel='culmen_depth_mm'>

# %%
sns.lineplot(x=df['body_mass_g'],y=df['culmen_depth_mm'],legend="auto")
# Out:
# c:\Users\mamil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\mamil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\mamil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.lineplot(x=df['body_mass_g'],y=df['culmen_depth_mm'],legend="auto",hue=df['species'])
# Out:
# c:\Users\mamil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\mamil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\mamil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.lineplot(x=df['body_mass_g'],y=df['culmen_depth_mm'],legend="auto",hue=df['sex'])
# Out:
# c:\Users\mamil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\mamil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\mamil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.pairplot(df)
# Out:
# c:\Users\mamil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\mamil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\mamil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
numeric_columns = df.select_dtypes(include=['number'])

# Calculate the correlation matrix
correlation_matrix = numeric_columns.corr()

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap (Numeric Columns Only)')

# Show the plot
plt.show()

# %% [markdown]
# descriptive statistics

# %%
df.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %%
df.isnull().any()
# Out:
# species              False
# island               False
# culmen_length_mm      True
# culmen_depth_mm       True
# flipper_length_mm     True
# body_mass_g           True
# sex                   True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
lenmedian=df['culmen_length_mm'].median();
df['culmen_length_mm'].fillna(lenmedian,inplace=True)

# %%
depthmedian=df['culmen_depth_mm'].median()
df['culmen_depth_mm'].fillna(depthmedian,inplace=True)

# %%
flipper=df['flipper_length_mm'].median()
df['flipper_length_mm'].fillna(flipper,inplace=True)

# %%
bodymass=df['body_mass_g'].median()
df['body_mass_g'].fillna(bodymass,inplace=True)

# %%
modesex=df['sex'].mode()[0]
df['sex'].fillna(modesex,inplace=True)

# %%
df.isnull().sum()
# Out:
# species              0
# island               0
# culmen_length_mm     0
# culmen_depth_mm      0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
df = df[df['sex'] != '.']
df = df.reset_index(drop=True)


df.sex.value_counts()
# Out:
# sex
# MALE      178
# FEMALE    165
# Name: count, dtype: int64

# %% [markdown]
# there is no outliers in the data

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen             39.10             18.7              181.0
# 1  Adelie  Torgersen             39.50             17.4              186.0
# 2  Adelie  Torgersen             40.30             18.0              195.0
# 3  Adelie  Torgersen             44.45             17.3              197.0
# 4  Adelie  Torgersen             36.70             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3       4050.0    MALE
# 4       3450.0  FEMALE

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['sex']=le.fit_transform(df['sex'])

# %%
df['species']=le.fit_transform(df['species'])

# %%
df['island']=le.fit_transform(df['island'])

# %%
y=df['species']
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 338    2
# 339    2
# 340    2
# 341    2
# 342    2
# Name: species, Length: 343, dtype: int32

# %%
x=df.drop(columns=['species'])

# %%
x
# Out:
#      island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0         2             39.10             18.7              181.0
# 1         2             39.50             17.4              186.0
# 2         2             40.30             18.0              195.0
# 3         2             44.45             17.3              197.0
# 4         2             36.70             19.3              193.0
# ..      ...               ...              ...                ...
# 338       0             44.45             17.3              197.0
# 339       0             46.80             14.3              215.0
# 340       0             50.40             15.7              222.0
# 341       0             45.20             14.8              212.0
# 342       0             49.90             16.1              213.0
#
#      body_mass_g  sex
# 0         3750.0    1
# 1         3800.0    0
# 2         3250.0    0
# 3         4050.0    1
# 4         3450.0    0
# ..           ...  ...
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
scaled=scaler.fit_transform(x)

# %%
pd.DataFrame(scaled,columns=x.columns)
# Out:
#        island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    1.840976         -0.886037         0.784618          -1.417863
# 1    1.840976         -0.812558         0.123879          -1.060638
# 2    1.840976         -0.665599         0.428836          -0.417631
# 3    1.840976          0.096750         0.073053          -0.274741
# 4    1.840976         -1.326914         1.089575          -0.560522
# ..        ...               ...              ...                ...
# 338 -0.916469          0.096750         0.073053          -0.274741
# 339 -0.916469          0.528441        -1.451729           1.011272
# 340 -0.916469          1.189756        -0.740164           1.511388
# 341 -0.916469          0.234524        -1.197599           0.796936
# 342 -0.916469          1.097906        -0.536860           0.868381
#
#      body_mass_g       sex
# 0      -0.561930  0.962791
# 1      -0.499342 -1.038647
# 2      -1.187818 -1.038647
# 3      -0.186398  0.962791
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(scaled,y,test_size=0.3,random_state=0)

# %%
x_train.shape
# Out:
# (240, 6)

# %%
x_test.shape
# Out:
# (103, 6)

# %%
y_train.shape
# Out:
# (240,)

# %%
y_test.shape
# Out:
# (103,)
