# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/House Price India.csv')
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
df.shape
# Out:
# (14620, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %%
df.isnull().any()
# Out:
# id                                       False
# Date                                     False
# number of bedrooms                       False
# number of bathrooms                      False
# living area                              False
# lot area                                 False
# number of floors                         False
# waterfront present                       False
# number of views                          False
# condition of the house                   False
# grade of the house                       False
# Area of the house(excluding basement)    False
# Area of the basement                     False
# Built Year                               False
# Renovation Year                          False
# Postal Code                              False
# Lattitude                                False
# Longitude                                False
# living_area_renov                        False
# lot_area_renov                           False
# ...

# %%
df.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
plt.figure(figsize=(8, 4))
sns.histplot(df['Price'], kde=True)
plt.title('Distribution of Price')
plt.show()

# %%
new_columns={'id':'id','Date':'Date','number of bedrooms':'no_of_bedrooms','number of bathrooms':'no_of_bathrooms','living area':'living_area','lot area':'lot_area',
             'number of floors':'n0_of_floors','waterfront present':'waterfront_present','number of views':'no_of_views','condition of the house':'condition_of_house',
             'grade of the house':'grade','Area of the house(excluding basement)':'total_area','Area of the basement':'area_basement','Built Year':'built_year',
             'Renovation Year':'reno_year','Postal Code':'postal_code','Lattitude':'Lattitude','Longitude':'Longitude','living_area_renov':'living_area_renov',
             'lot_area_renov':'lot_area_renov','Number of schools nearby':'schools','Distance from the airport':'dist_airport','Price':'Price'}
df.rename(columns=new_columns, inplace=True)

# %%
df
# Out:
#                id   Date  no_of_bedrooms  no_of_bathrooms  living_area  \
# 0      6762810145  42491               5             2.50         3650
# 1      6762810635  42491               4             2.50         2920
# 2      6762810998  42491               5             2.75         2910
# 3      6762812605  42491               4             2.50         3310
# 4      6762812919  42491               3             2.00         2710
# ...           ...    ...             ...              ...          ...
# 14615  6762830250  42734               2             1.50         1556
# 14616  6762830339  42734               3             2.00         1680
# 14617  6762830618  42734               2             1.00         1070
# 14618  6762830709  42734               4             1.00         1030
# 14619  6762831463  42734               3             1.00          900
#
#        lot_area  n0_of_floors  waterfront_present  no_of_views  \
# ...

# %%
df.describe()
# Out:
#                  id          Date  no_of_bedrooms  no_of_bathrooms  \
# count  1.462000e+04  14620.000000    14620.000000     14620.000000
# mean   6.762821e+09  42604.538646        3.379343         2.129583
# std    6.237575e+03     67.347991        0.938719         0.769934
# min    6.762810e+09  42491.000000        1.000000         0.500000
# 25%    6.762815e+09  42546.000000        3.000000         1.750000
# 50%    6.762821e+09  42600.000000        3.000000         2.250000
# 75%    6.762826e+09  42662.000000        4.000000         2.500000
# max    6.762832e+09  42734.000000       33.000000         8.000000
#
#         living_area      lot_area  n0_of_floors  waterfront_present  \
# count  14620.000000  1.462000e+04  14620.000000        14620.000000
# mean    2098.262996  1.509328e+04      1.502360            0.007661
# std      928.275721  3.791962e+04      0.540239            0.087193
# min      370.000000  5.200000e+02      1.000000            0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  14620 non-null  int64
#  1   Date                14620 non-null  int64
#  2   no_of_bedrooms      14620 non-null  int64
#  3   no_of_bathrooms     14620 non-null  float64
#  4   living_area         14620 non-null  int64
#  5   lot_area            14620 non-null  int64
#  6   n0_of_floors        14620 non-null  float64
#  7   waterfront_present  14620 non-null  int64
#  8   no_of_views         14620 non-null  int64
#  9   condition_of_house  14620 non-null  int64
#  10  grade               14620 non-null  int64
#  11  total_area          14620 non-null  int64
#  12  area_basement       14620 non-null  int64
#  13  built_year          14620 non-null  int64
#  14  reno_year           14620 non-null  int64
# ...

# %%
df.no_of_bedrooms.unique()
# Out:
# array([ 5,  4,  3,  2,  7,  6,  9,  1,  8, 33, 10, 11])

# %%
df.waterfront_present.unique()
# Out:
# array([0, 1])

# %%
df.no_of_views.unique()
# Out:
# array([4, 0, 2, 1, 3])

# %%
df.schools.unique()
# Out:
# array([2, 1, 3])

# %% [markdown]
# TASK-2
# UNIVARIANT ANALYSIS

# %%
plt.figure(figsize=(8, 4))
sns.histplot(df['Price'], kde=True)
plt.title('Distribution of Price')
plt.show()

# %%
sns.distplot(df.Price)
# Out:
# <ipython-input-18-5e080168c38c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Price)
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.displot(df.n0_of_floors)

# %%
plt.pie(df.waterfront_present.value_counts(),[0,0.1],labels=['NO','yes'],autopct='%1.1f%%',shadow=True,colors=['red','green'])
plt.title("Water_front")
plt.legend(['NO','YES'])
plt.show()

# %%
plt.pie(df.schools.value_counts(),[0,0.1,0.1],labels=['TWO','THREE','ONE'],autopct='%1.1f%%',shadow=True,colors=['red','green','yellow'])
plt.title("No.of schools")
plt.legend(['TWO','THREE','ONE'])
plt.show()

# %%
df.condition_of_house.unique()
# Out:
# array([5, 3, 4, 2, 1])

# %%
sns.barplot(x=df.condition_of_house.value_counts().index,y=df.condition_of_house.value_counts())
# Out:
# <Axes: ylabel='condition_of_house'>

# %%
sns.barplot(x=df.no_of_bedrooms.value_counts().index,y=df.no_of_bedrooms.value_counts())
# Out:
# <Axes: ylabel='no_of_bedrooms'>

# %%
sns.boxplot(df.Price)
# Out:
# <Axes: >

# %% [markdown]
# BIVARIATE ANALYSIS

# %%
sns.lineplot(x=df.no_of_bedrooms,y=df.Price)
# Out:
# <Axes: xlabel='no_of_bedrooms', ylabel='Price'>

# %%
sns.lineplot(x=df.condition_of_house,y=df.Price)
# Out:
# <Axes: xlabel='condition_of_house', ylabel='Price'>

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='total_area', y='Price')
plt.title('Area vs Price')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='built_year', y='Price')
plt.title('Built_Year vs Price')
plt.show()

# %% [markdown]
# MULTI VARIATE ANALYSIS

# %%
df.corr()
# Out:
#                           id      Date  no_of_bedrooms  no_of_bathrooms  \
# id                  1.000000  0.045966       -0.329034        -0.516909
# Date                0.045966  1.000000       -0.015663        -0.026485
# no_of_bedrooms     -0.329034 -0.015663        1.000000         0.509784
# no_of_bathrooms    -0.516909 -0.026485        0.509784         1.000000
# living_area        -0.648127 -0.021958        0.570526         0.753517
# lot_area           -0.100269  0.004392        0.034416         0.080806
# n0_of_floors       -0.312305 -0.010335        0.177294         0.502924
# waterfront_present -0.112937  0.012006       -0.006257         0.060104
# no_of_views        -0.293004 -0.004782        0.078665         0.183789
# condition_of_house -0.045061 -0.027402        0.026597        -0.128232
# grade              -0.673448 -0.033097        0.352945         0.663054
# total_area         -0.565116 -0.015994        0.473599         0.684391
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# TASK3

# %% [markdown]
# HANDLING MISSING VALUES

# %%
df.isnull().any()
# Out:
# id                    False
# Date                  False
# no_of_bedrooms        False
# no_of_bathrooms       False
# living_area           False
# lot_area              False
# n0_of_floors          False
# waterfront_present    False
# no_of_views           False
# condition_of_house    False
# grade                 False
# total_area            False
# area_basement         False
# built_year            False
# reno_year             False
# postal_code           False
# Lattitude             False
# Longitude             False
# living_area_renov     False
# lot_area_renov        False
# schools               False
# dist_airport          False
# Price                 False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# id                    0
# Date                  0
# no_of_bedrooms        0
# no_of_bathrooms       0
# living_area           0
# lot_area              0
# n0_of_floors          0
# waterfront_present    0
# no_of_views           0
# condition_of_house    0
# grade                 0
# total_area            0
# area_basement         0
# built_year            0
# reno_year             0
# postal_code           0
# Lattitude             0
# Longitude             0
# living_area_renov     0
# lot_area_renov        0
# schools               0
# dist_airport          0
# Price                 0
# dtype: int64

# %% [markdown]
# TASK 4
# DESCRIPTIVE STATISTICS

# %%
df.describe()
# Out:
#                  id          Date  no_of_bedrooms  no_of_bathrooms  \
# count  1.462000e+04  14620.000000    14620.000000     14620.000000
# mean   6.762821e+09  42604.538646        3.379343         2.129583
# std    6.237575e+03     67.347991        0.938719         0.769934
# min    6.762810e+09  42491.000000        1.000000         0.500000
# 25%    6.762815e+09  42546.000000        3.000000         1.750000
# 50%    6.762821e+09  42600.000000        3.000000         2.250000
# 75%    6.762826e+09  42662.000000        4.000000         2.500000
# max    6.762832e+09  42734.000000       33.000000         8.000000
#
#         living_area      lot_area  n0_of_floors  waterfront_present  \
# count  14620.000000  1.462000e+04  14620.000000        14620.000000
# mean    2098.262996  1.509328e+04      1.502360            0.007661
# std      928.275721  3.791962e+04      0.540239            0.087193
# min      370.000000  5.200000e+02      1.000000            0.000000
# ...
